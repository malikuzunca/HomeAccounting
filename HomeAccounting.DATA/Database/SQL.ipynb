-- %% [markdown]
-- # [dbo].[AspNetRoleClaims]

-- %%
USE [HomeAccountingDB]
GO

-- %%
/****** Object:  Table [dbo].[AspNetRoleClaims]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetRoleClaims](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [nvarchar](450) NOT NULL,
	[ClaimType] [nvarchar](max) NULL,
	[ClaimValue] [nvarchar](max) NULL,
 CONSTRAINT [PK_AspNetRoleClaims] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetRoles]

-- %%
/****** Object:  Table [dbo].[AspNetRoles]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetRoles](
	[Id] [nvarchar](450) NOT NULL,
	[Name] [nvarchar](256) NULL,
	[NormalizedName] [nvarchar](256) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
 CONSTRAINT [PK_AspNetRoles] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserClaims]

-- %%
/****** Object:  Table [dbo].[AspNetUserClaims]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserClaims](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [nvarchar](450) NOT NULL,
	[ClaimType] [nvarchar](max) NULL,
	[ClaimValue] [nvarchar](max) NULL,
 CONSTRAINT [PK_AspNetUserClaims] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserLogins]

-- %%
/****** Object:  Table [dbo].[AspNetUserLogins]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserLogins](
	[LoginProvider] [nvarchar](450) NOT NULL,
	[ProviderKey] [nvarchar](450) NOT NULL,
	[ProviderDisplayName] [nvarchar](max) NULL,
	[UserId] [nvarchar](450) NOT NULL,
 CONSTRAINT [PK_AspNetUserLogins] PRIMARY KEY CLUSTERED 
(
	[LoginProvider] ASC,
	[ProviderKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserRoles]

-- %%
/****** Object:  Table [dbo].[AspNetUserRoles]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserRoles](
	[UserId] [nvarchar](450) NOT NULL,
	[RoleId] [nvarchar](450) NOT NULL,
 CONSTRAINT [PK_AspNetUserRoles] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[RoleId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUsers]

-- %%
/****** Object:  Table [dbo].[AspNetUsers]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUsers](
	[Id] [nvarchar](450) NOT NULL,
	[UserName] [nvarchar](256) NULL,
	[NormalizedUserName] [nvarchar](256) NULL,
	[Email] [nvarchar](256) NULL,
	[NormalizedEmail] [nvarchar](256) NULL,
	[EmailConfirmed] [bit] NOT NULL,
	[PasswordHash] [nvarchar](max) NULL,
	[SecurityStamp] [nvarchar](max) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
	[PhoneNumber] [nvarchar](max) NULL,
	[PhoneNumberConfirmed] [bit] NOT NULL,
	[TwoFactorEnabled] [bit] NOT NULL,
	[LockoutEnd] [datetimeoffset](7) NULL,
	[LockoutEnabled] [bit] NOT NULL,
	[AccessFailedCount] [int] NOT NULL,
 CONSTRAINT [PK_AspNetUsers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserTokens]

-- %%
/****** Object:  Table [dbo].[AspNetUserTokens]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserTokens](
	[UserId] [nvarchar](450) NOT NULL,
	[LoginProvider] [nvarchar](450) NOT NULL,
	[Name] [nvarchar](450) NOT NULL,
	[Value] [nvarchar](max) NULL,
 CONSTRAINT [PK_AspNetUserTokens] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[LoginProvider] ASC,
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlogCategoryContent]

-- %%
/****** Object:  Table [dbo].[tblBlogCategoryContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlogCategoryContent](
	[BlogCategorySubID] [int] IDENTITY(1,1) NOT NULL,
	[BlogCategoryID] [int] NULL,
	[LangID] [int] NULL,
	[BlogCategorySubName] [nvarchar](50) NULL,
	[Title] [nvarchar](70) NULL,
	[Description] [nvarchar](150) NULL,
	[URL] [nvarchar](100) NULL,
 CONSTRAINT [PK_tblBlogCategoryContent] PRIMARY KEY CLUSTERED 
(
	[BlogCategorySubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlogCategoryMain]

-- %%
/****** Object:  Table [dbo].[tblBlogCategoryMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlogCategoryMain](
	[BlogCategoryID] [int] IDENTITY(1,1) NOT NULL,
	[BlogCategoryName] [nvarchar](50) NULL,
	[Arrangement] [int] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblBlogCategoryMain] PRIMARY KEY CLUSTERED 
(
	[BlogCategoryID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlogPostContent]

-- %%
/****** Object:  Table [dbo].[tblBlogPostContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlogPostContent](
	[BlogPostSubID] [int] IDENTITY(1,1) NOT NULL,
	[BlogPostID] [int] NULL,
	[LangID] [int] NULL,
	[BlogPostSubName] [nvarchar](255) NULL,
	[BlogPostShortText] [nvarchar](max) NULL,
	[BlogPostContent] [ntext] NULL,
	[ClickCount] [int] NULL,
	[Title] [nvarchar](255) NULL,
	[Description] [nvarchar](max) NULL,
	[URL] [nvarchar](255) NULL,
 CONSTRAINT [PK_tblBlogPostContent] PRIMARY KEY CLUSTERED 
(
	[BlogPostSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlogPostMain]

-- %%
/****** Object:  Table [dbo].[tblBlogPostMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlogPostMain](
	[BlogPostID] [int] IDENTITY(1,1) NOT NULL,
	[BlogCategoryID] [int] NULL,
	[BlogPostName] [nvarchar](255) NULL,
	[ListImage] [nvarchar](255) NULL,
	[Arrangement] [int] NULL,
	[RegisterDate] [datetime] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblBlogPostMain] PRIMARY KEY CLUSTERED 
(
	[BlogPostID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblCmsContent]

-- %%
/****** Object:  Table [dbo].[tblCmsContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCmsContent](
	[CmsSubID] [int] IDENTITY(1,1) NOT NULL,
	[CmsID] [int] NULL,
	[LangID] [int] NULL,
	[CmsSubName] [nvarchar](255) NULL,
	[CmsContent] [ntext] NULL,
	[Title] [nvarchar](150) NULL,
	[Description] [ntext] NULL,
	[URL] [nvarchar](255) NULL,
 CONSTRAINT [PK_tblCmsContent] PRIMARY KEY CLUSTERED 
(
	[CmsSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblCmsMain]

-- %%
/****** Object:  Table [dbo].[tblCmsMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCmsMain](
	[CmsID] [int] IDENTITY(1,1) NOT NULL,
	[CmsType] [int] NULL,
	[CmsSub] [int] NULL,
	[CmsName] [nvarchar](255) NULL,
	[ExternalURL] [nvarchar](max) NULL,
	[Arrangement] [int] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblCmsMain] PRIMARY KEY CLUSTERED 
(
	[CmsID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblHomeContent]

-- %%
/****** Object:  Table [dbo].[tblHomeContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblHomeContent](
	[HomeSubID] [int] NOT NULL,
	[HomeID] [int] NULL,
	[HomeSubName] [nvarchar](50) NULL,
	[Title] [nvarchar](100) NULL,
	[Description] [nvarchar](500) NULL,
	[URL] [nvarchar](500) NULL,
 CONSTRAINT [PK_tblHomeContent] PRIMARY KEY CLUSTERED 
(
	[HomeSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblHomeExpenseMain]

-- %%
/****** Object:  Table [dbo].[tblHomeExpenseMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblHomeExpenseMain](
	[ExpenseID] [int] NOT NULL,
	[HomeID] [int] NOT NULL,
 CONSTRAINT [PK_tblHomeExpenseMain] PRIMARY KEY CLUSTERED 
(
	[ExpenseID] ASC,
	[HomeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblHomeExpenses]

-- %%
/****** Object:  Table [dbo].[tblHomeExpenses]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblHomeExpenses](
	[ExpenseID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [nvarchar](500) NULL,
	[ExpenseName] [nvarchar](250) NULL,
	[ExpensePrice] [int] NULL,
	[IsFixed] [bit] NULL,
 CONSTRAINT [PK_tblHomeExpenses] PRIMARY KEY CLUSTERED 
(
	[ExpenseID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblHomeMain]

-- %%
/****** Object:  Table [dbo].[tblHomeMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblHomeMain](
	[HomeID] [int] IDENTITY(1,1) NOT NULL,
	[Arrangement] [int] NULL,
	[HomeName] [nvarchar](50) NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblHomeMain] PRIMARY KEY CLUSTERED 
(
	[HomeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblLink]

-- %%
/****** Object:  Table [dbo].[tblLink]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblLink](
	[LinkID] [int] IDENTITY(1,1) NOT NULL,
	[Link] [nvarchar](500) NULL,
	[Controller] [nvarchar](100) NULL,
	[Action] [nvarchar](100) NULL,
	[GroupID] [nvarchar](100) NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblLink] PRIMARY KEY CLUSTERED 
(
	[LinkID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblLinkInfo]

-- %%
/****** Object:  Table [dbo].[tblLinkInfo]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblLinkInfo](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Text] [nvarchar](250) NULL,
	[Controller] [nvarchar](100) NULL,
	[Action] [nvarchar](100) NULL,
 CONSTRAINT [PK_tblLinkInfo] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblMoneyIncome]

-- %%
/****** Object:  Table [dbo].[tblMoneyIncome]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblMoneyIncome](
	[IncomeID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [nvarchar](500) NULL,
	[IncomeName] [nvarchar](250) NULL,
	[IncomeDescription] [nvarchar](500) NULL,
	[IncomePrice] [nvarchar](50) NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblMoneyIncome] PRIMARY KEY CLUSTERED 
(
	[IncomeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblServiceContent]

-- %%
/****** Object:  Table [dbo].[tblServiceContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblServiceContent](
	[ServiceSubID] [int] IDENTITY(1,1) NOT NULL,
	[ServiceID] [int] NULL,
	[LangID] [int] NULL,
	[ServiceSubName] [nvarchar](500) NULL,
	[ServiceContent] [nvarchar](max) NULL,
	[ImageURL] [nvarchar](500) NULL,
	[Title] [nvarchar](500) NULL,
	[Description] [nvarchar](500) NULL,
	[URL] [nvarchar](500) NULL,
 CONSTRAINT [PK_tblServiceContent] PRIMARY KEY CLUSTERED 
(
	[ServiceSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblServiceMain]

-- %%
/****** Object:  Table [dbo].[tblServiceMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblServiceMain](
	[ServiceID] [int] IDENTITY(1,1) NOT NULL,
	[ServiceName] [nvarchar](500) NULL,
	[ListImage] [varchar](max) NULL,
	[Arrangement] [int] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblServiceMain] PRIMARY KEY CLUSTERED 
(
	[ServiceID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblSSSCategoryContent]

-- %%
/****** Object:  Table [dbo].[tblSSSCategoryContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblSSSCategoryContent](
	[SSSCategorySubID] [int] IDENTITY(1,1) NOT NULL,
	[SSSCategoryID] [int] NULL,
	[LangID] [int] NULL,
	[CategorySubName] [nvarchar](50) NULL,
	[Title] [nvarchar](130) NULL,
	[Description] [nvarchar](150) NULL,
	[URL] [nvarchar](50) NULL,
 CONSTRAINT [PK_tblSSSCategoryContent] PRIMARY KEY CLUSTERED 
(
	[SSSCategorySubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblSSSCategoryMain]

-- %%
/****** Object:  Table [dbo].[tblSSSCategoryMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblSSSCategoryMain](
	[SSSCategoryID] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [nvarchar](50) NULL,
	[ListImage] [varchar](max) NULL,
	[Arrangement] [int] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblSSSCategoryMain] PRIMARY KEY CLUSTERED 
(
	[SSSCategoryID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblSSSPostContent]

-- %%
/****** Object:  Table [dbo].[tblSSSPostContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblSSSPostContent](
	[SSSPostSubID] [int] IDENTITY(1,1) NOT NULL,
	[SSSPostID] [int] NULL,
	[LangID] [int] NULL,
	[SubQuestion] [nvarchar](max) NULL,
	[SubAnswer] [nvarchar](max) NULL,
	[Title] [nvarchar](max) NULL,
	[Description] [nvarchar](max) NULL,
	[URL] [nvarchar](max) NULL,
 CONSTRAINT [PK_tblSSSPostContent] PRIMARY KEY CLUSTERED 
(
	[SSSPostSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblSSSPostMain]

-- %%
/****** Object:  Table [dbo].[tblSSSPostMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblSSSPostMain](
	[SSSPostID] [int] IDENTITY(1,1) NOT NULL,
	[CategoryID] [int] NULL,
	[SSSPostName] [nvarchar](255) NULL,
	[Arrangement] [int] NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblSSSPostMain] PRIMARY KEY CLUSTERED 
(
	[SSSPostID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblSystemSetting]

-- %%
/****** Object:  Table [dbo].[tblSystemSetting]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblSystemSetting](
	[SystemID] [int] IDENTITY(1,1) NOT NULL,
	[BusinesName] [nvarchar](250) NULL,
	[EmailAdress] [nvarchar](500) NULL,
	[PhoneNumber] [nvarchar](150) NULL,
	[LogoURL] [nvarchar](500) NULL,
	[Adress] [nvarchar](500) NULL,
	[HeadCode] [nvarchar](max) NULL,
	[BodyCode] [nvarchar](max) NULL,
	[CdnURL] [nvarchar](500) NULL,
	[FtpURL] [nvarchar](500) NULL,
	[MapURL] [nvarchar](500) NULL,
 CONSTRAINT [PK_tblSystemSetting] PRIMARY KEY CLUSTERED 
(
	[SystemID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblUserDetail]

-- %%
/****** Object:  Table [dbo].[tblUserDetail]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblUserDetail](
	[ElementID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [nvarchar](450) NULL,
	[NameSurname] [nvarchar](250) NULL,
	[EmailAdress] [nvarchar](250) NULL,
	[Password] [nvarchar](250) NULL,
	[Company] [nvarchar](100) NULL,
	[PhoneNumber] [nvarchar](50) NULL,
 CONSTRAINT [PK_tblUserDetail] PRIMARY KEY CLUSTERED 
(
	[ElementID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblUserLoginType]

-- %%
/****** Object:  Table [dbo].[tblUserLoginType]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblUserLoginType](
	[ElementID] [int] NULL,
	[UserID] [nvarchar](450) NULL,
	[LoginType] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblVehicleContent]

-- %%
/****** Object:  Table [dbo].[tblVehicleContent]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblVehicleContent](
	[VehicleSubID] [int] IDENTITY(1,1) NOT NULL,
	[VehicleID] [int] NULL,
	[VehicleSubName] [nvarchar](250) NULL,
	[Title] [nvarchar](250) NULL,
	[Description] [nvarchar](500) NULL,
	[URL] [nvarchar](250) NULL,
 CONSTRAINT [PK_tblVehicleContent] PRIMARY KEY CLUSTERED 
(
	[VehicleSubID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblVehicleExpenseMain]

-- %%
/****** Object:  Table [dbo].[tblVehicleExpenseMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblVehicleExpenseMain](
	[ExpenseID] [int] NOT NULL,
	[VehicleID] [int] NOT NULL,
 CONSTRAINT [PK_tblVehicleExpenseMain] PRIMARY KEY CLUSTERED 
(
	[ExpenseID] ASC,
	[VehicleID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblVehicleExpenses]

-- %%
/****** Object:  Table [dbo].[tblVehicleExpenses]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblVehicleExpenses](
	[ExpenseID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [nvarchar](450) NULL,
	[ExpenseName] [nvarchar](250) NULL,
	[ExpensePrice] [nvarchar](150) NULL,
 CONSTRAINT [PK_tblVehicleExpenses] PRIMARY KEY CLUSTERED 
(
	[ExpenseID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblVehicleMain]

-- %%
/****** Object:  Table [dbo].[tblVehicleMain]    Script Date: 18.05.2025 03:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblVehicleMain](
	[VehicleID] [int] IDENTITY(1,1) NOT NULL,
	[Arrangement] [int] NULL,
	[VehicleName] [nvarchar](250) NULL,
	[Brand] [nvarchar](50) NULL,
	[Model] [nvarchar](50) NULL,
	[Kilometers] [nvarchar](250) NULL,
	[IsActive] [bit] NULL,
	[Deleted] [bit] NULL,
 CONSTRAINT [PK_tblVehicleMain] PRIMARY KEY CLUSTERED 
(
	[VehicleID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_tblBlogCategoryMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblBlogCategoryMain] ADD  CONSTRAINT [DF_tblBlogCategoryMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblBlogCategoryMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblBlogCategoryMain] ADD  CONSTRAINT [DF_tblBlogCategoryMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblBlogPostContent_ClickCount]

-- %%
ALTER TABLE [dbo].[tblBlogPostContent] ADD  CONSTRAINT [DF_tblBlogPostContent_ClickCount]  DEFAULT ((0)) FOR [ClickCount]
GO

-- %% [markdown]
-- # [DF_tblBlogPostMain_RegisterDate]

-- %%
ALTER TABLE [dbo].[tblBlogPostMain] ADD  CONSTRAINT [DF_tblBlogPostMain_RegisterDate]  DEFAULT (getdate()) FOR [RegisterDate]
GO

-- %% [markdown]
-- # [DF_tblBlogPostMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblBlogPostMain] ADD  CONSTRAINT [DF_tblBlogPostMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblBlogPostMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblBlogPostMain] ADD  CONSTRAINT [DF_tblBlogPostMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblCmsMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblCmsMain] ADD  CONSTRAINT [DF_tblCmsMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblCmsMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblCmsMain] ADD  CONSTRAINT [DF_tblCmsMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblHomeExpenses_IsFixed]

-- %%
ALTER TABLE [dbo].[tblHomeExpenses] ADD  CONSTRAINT [DF_tblHomeExpenses_IsFixed]  DEFAULT ((0)) FOR [IsFixed]
GO

-- %% [markdown]
-- # [DF_tblHomeMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblHomeMain] ADD  CONSTRAINT [DF_tblHomeMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblHomeMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblHomeMain] ADD  CONSTRAINT [DF_tblHomeMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblLink_IsActive]

-- %%
ALTER TABLE [dbo].[tblLink] ADD  CONSTRAINT [DF_tblLink_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblLink_Deleted]

-- %%
ALTER TABLE [dbo].[tblLink] ADD  CONSTRAINT [DF_tblLink_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblMoneyIncome_IsActive]

-- %%
ALTER TABLE [dbo].[tblMoneyIncome] ADD  CONSTRAINT [DF_tblMoneyIncome_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblMoneyIncome_Deleted]

-- %%
ALTER TABLE [dbo].[tblMoneyIncome] ADD  CONSTRAINT [DF_tblMoneyIncome_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblServiceMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblServiceMain] ADD  CONSTRAINT [DF_tblServiceMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblServiceMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblServiceMain] ADD  CONSTRAINT [DF_tblServiceMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblSSSCategoryMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblSSSCategoryMain] ADD  CONSTRAINT [DF_tblSSSCategoryMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblSSSCategoryMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblSSSCategoryMain] ADD  CONSTRAINT [DF_tblSSSCategoryMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblSSSPostMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblSSSPostMain] ADD  CONSTRAINT [DF_tblSSSPostMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblSSSPostMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblSSSPostMain] ADD  CONSTRAINT [DF_tblSSSPostMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF_tblVehicleMain_IsActive]

-- %%
ALTER TABLE [dbo].[tblVehicleMain] ADD  CONSTRAINT [DF_tblVehicleMain_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_tblVehicleMain_Deleted]

-- %%
ALTER TABLE [dbo].[tblVehicleMain] ADD  CONSTRAINT [DF_tblVehicleMain_Deleted]  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [FK_tblBlogPostMain_tblBlogCategoryMain]

-- %%
ALTER TABLE [dbo].[tblBlogPostMain]  WITH CHECK ADD  CONSTRAINT [FK_tblBlogPostMain_tblBlogCategoryMain] FOREIGN KEY([BlogCategoryID])
REFERENCES [dbo].[tblBlogCategoryMain] ([BlogCategoryID])
GO
ALTER TABLE [dbo].[tblBlogPostMain] CHECK CONSTRAINT [FK_tblBlogPostMain_tblBlogCategoryMain]
GO

-- %% [markdown]
-- # [FK_tblHomeContent_tblHomeMain]

-- %%
ALTER TABLE [dbo].[tblHomeContent]  WITH CHECK ADD  CONSTRAINT [FK_tblHomeContent_tblHomeMain] FOREIGN KEY([HomeID])
REFERENCES [dbo].[tblHomeMain] ([HomeID])
GO
ALTER TABLE [dbo].[tblHomeContent] CHECK CONSTRAINT [FK_tblHomeContent_tblHomeMain]
GO

-- %% [markdown]
-- # [FK_tblHomeExpenseMain_tblHomeExpenses]

-- %%
ALTER TABLE [dbo].[tblHomeExpenseMain]  WITH CHECK ADD  CONSTRAINT [FK_tblHomeExpenseMain_tblHomeExpenses] FOREIGN KEY([ExpenseID])
REFERENCES [dbo].[tblHomeExpenses] ([ExpenseID])
GO
ALTER TABLE [dbo].[tblHomeExpenseMain] CHECK CONSTRAINT [FK_tblHomeExpenseMain_tblHomeExpenses]
GO

-- %% [markdown]
-- # [FK_tblHomeExpenseMain_tblHomeMain]

-- %%
ALTER TABLE [dbo].[tblHomeExpenseMain]  WITH CHECK ADD  CONSTRAINT [FK_tblHomeExpenseMain_tblHomeMain] FOREIGN KEY([HomeID])
REFERENCES [dbo].[tblHomeMain] ([HomeID])
GO
ALTER TABLE [dbo].[tblHomeExpenseMain] CHECK CONSTRAINT [FK_tblHomeExpenseMain_tblHomeMain]
GO

-- %% [markdown]
-- # [FK_tblUserDetail_AspNetUsers]

-- %%
ALTER TABLE [dbo].[tblUserDetail]  WITH CHECK ADD  CONSTRAINT [FK_tblUserDetail_AspNetUsers] FOREIGN KEY([UserID])
REFERENCES [dbo].[AspNetUsers] ([Id])
GO
ALTER TABLE [dbo].[tblUserDetail] CHECK CONSTRAINT [FK_tblUserDetail_AspNetUsers]
GO

-- %% [markdown]
-- # [FK_tblUserLoginType_AspNetUsers]

-- %%
ALTER TABLE [dbo].[tblUserLoginType]  WITH CHECK ADD  CONSTRAINT [FK_tblUserLoginType_AspNetUsers] FOREIGN KEY([UserID])
REFERENCES [dbo].[AspNetUsers] ([Id])
GO
ALTER TABLE [dbo].[tblUserLoginType] CHECK CONSTRAINT [FK_tblUserLoginType_AspNetUsers]
GO

-- %% [markdown]
-- # [FK_tblUserLoginType_tblUserDetail]

-- %%
ALTER TABLE [dbo].[tblUserLoginType]  WITH CHECK ADD  CONSTRAINT [FK_tblUserLoginType_tblUserDetail] FOREIGN KEY([ElementID])
REFERENCES [dbo].[tblUserDetail] ([ElementID])
GO
ALTER TABLE [dbo].[tblUserLoginType] CHECK CONSTRAINT [FK_tblUserLoginType_tblUserDetail]
GO

-- %% [markdown]
-- # [FK_tblVehicleContent_tblVehicleMain]

-- %%
ALTER TABLE [dbo].[tblVehicleContent]  WITH CHECK ADD  CONSTRAINT [FK_tblVehicleContent_tblVehicleMain] FOREIGN KEY([VehicleID])
REFERENCES [dbo].[tblVehicleMain] ([VehicleID])
GO
ALTER TABLE [dbo].[tblVehicleContent] CHECK CONSTRAINT [FK_tblVehicleContent_tblVehicleMain]
GO

-- %% [markdown]
-- # [FK_tblVehicleExpenseMain_tblVehicleExpenses]

-- %%
ALTER TABLE [dbo].[tblVehicleExpenseMain]  WITH CHECK ADD  CONSTRAINT [FK_tblVehicleExpenseMain_tblVehicleExpenses] FOREIGN KEY([ExpenseID])
REFERENCES [dbo].[tblVehicleExpenses] ([ExpenseID])
GO
ALTER TABLE [dbo].[tblVehicleExpenseMain] CHECK CONSTRAINT [FK_tblVehicleExpenseMain_tblVehicleExpenses]
GO

-- %% [markdown]
-- # [FK_tblVehicleExpenseMain_tblVehicleMain]

-- %%
ALTER TABLE [dbo].[tblVehicleExpenseMain]  WITH CHECK ADD  CONSTRAINT [FK_tblVehicleExpenseMain_tblVehicleMain] FOREIGN KEY([VehicleID])
REFERENCES [dbo].[tblVehicleMain] ([VehicleID])
GO
ALTER TABLE [dbo].[tblVehicleExpenseMain] CHECK CONSTRAINT [FK_tblVehicleExpenseMain_tblVehicleMain]
GO
